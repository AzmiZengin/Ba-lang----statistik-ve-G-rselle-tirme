# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data= pd.read_csv("data.csv")
data.head()
# Out:
#      OrderDate   Region      Rep     Item  Units  Unit Price
# 0   4-Jul-2014     East  Richard  Pen Set     62        4.99
# 1  12-Jul-2014     East     Nick   Binder     29        1.99
# 2  21-Jul-2014  Central   Morgan  Pen Set     55       12.49
# 3  29-Jul-2014     East    Susan   Binder     81       19.99
# 4   7-Aug-2014  Central  Matthew  Pen Set     42       23.95

# %%
data.shape
# Out:
# (43, 6)

# %%
data.isnull().sum()
# Out:
# OrderDate     0
# Region        0
# Rep           0
# Item          0
# Units         0
# Unit Price    0
# dtype: int64

# %%
data.describe()
# Out:
#            Units  Unit Price
# count  43.000000   43.000000
# mean   49.325581   20.308605
# std    30.078248   47.345118
# min     2.000000    1.290000
# 25%    27.500000    3.990000
# 50%    53.000000    4.990000
# 75%    74.500000   17.990000
# max    96.000000  275.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   OrderDate   43 non-null     object
#  1   Region      43 non-null     object
#  2   Rep         43 non-null     object
#  3   Item        43 non-null     object
#  4   Units       43 non-null     int64
#  5   Unit Price  43 non-null     float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 2.1+ KB

# %%
x=data["OrderDate"]
y=data["Unit Price"]
plt.bar(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x=data["OrderDate"]
y=data["Unit Price"]
plt.figure(figsize=(15,8))
plt.bar(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x=range(1,44)
y=data["Unit Price"]
plt.bar(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x=range(1,44)
y=data["Unit Price"]
plt.bar(x,y)
plt.xticks(np.arange(1,44,1))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data.head(10)
# Out:
#      OrderDate   Region      Rep     Item  Units  Unit Price
# 0   4-Jul-2014     East  Richard  Pen Set     62        4.99
# 1  12-Jul-2014     East     Nick   Binder     29        1.99
# 2  21-Jul-2014  Central   Morgan  Pen Set     55       12.49
# 3  29-Jul-2014     East    Susan   Binder     81       19.99
# 4   7-Aug-2014  Central  Matthew  Pen Set     42       23.95
# 5  15-Aug-2014     East  Richard   Pencil     35        4.99
# 6  24-Aug-2014     West    James     Desk      3      275.00
# 7   1-Sep-2014  Central    Smith     Desk      2      125.00
# 8  10-Sep-2014  Central     Bill   Pencil      7        1.29
# 9  18-Sep-2014     East  Richard  Pen Set     16       15.99

# %%
x=range(1,44)
y=data["Unit Price"]
plt.bar(x,y, color= "purple", width=0.5)
plt.xlabel("Günler")
plt.ylabel("Birim Fiyat")
plt.title("SATIŞ TABLOSU")
plt.xticks(np.arange(1,44,1))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x=range(1,44)
y=data["Unit Price"]
plt.bar(x,y, color= "purple", width=0.5)
plt.xlabel("Günler")
plt.ylabel("Birim Fiyat")
plt.title("SATIŞ TABLOSU")
plt.xticks(np.arange(1,44,1))
plt.plot(x,y, color= "cyan")
plt.legend(labels = ["Satışlar"])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
satışlar= data.groupby("Item")
satışlar=satışlar.sum()
satışlar=satışlar.plot()

# %%
satışlar= data.groupby("Item")
satışlar=satışlar.sum()
satışlar=satışlar.plot(kind="bar")
satışlar.set_ylabel("Miktar & Birim Fiyat")
# Out:
# Text(0, 0.5, 'Miktar & Birim Fiyat')
